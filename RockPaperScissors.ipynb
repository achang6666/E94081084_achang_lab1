# %%
import random
print("Welcome to ROCK, PAPER, SCISSORS game!") #0石頭 1布 2剪刀
win=0
i=0#使用者輸入
a=0#平局數
b=0#輸數

while win==0:
    print("Enter your move: (r)ock (p)aper (s)cissors")
    ran=random.randrange(3)
    if input()=='r':
        i=0
        if ran==0:
            print('ROCK versus...')
            print("ROCK")
            print("It's a tie!")
            a=a+1
        elif ran==1:
            print('ROCK versus...')
            print("PAPER")
            print("You lose!")
            b=b+1
        elif ran==2:
            print('ROCK versus...')
            print("SCISSORS")
            print("You win!")
            print("You have ",a,"ties and ",b,"losses before your first win.")
            win=1
            a=0
            b=0
    elif input()=='p':
        i=1
        if ran==0:
            print('PAPER versus...')
            print("ROCK")
            print("You win!")
            print("You have ",a,"ties and ",b,"losses before your first win.")
            win=1
            a=0
            b=0
        elif ran==1:
            print('PAPER versus...')
            print("PAPER")
            print("It's a tie!")
            a=a+1
        elif ran==2:
            print('PAPER versus...')
            print("SCISSORS")
            print("You lose!")
            b=b+1
    elif input()=='s':
        i=2
        if ran==0:
            print('SCISSORS versus...')
            print("ROCK")
            print("You lose!")
            b=b+1
        elif ran==1:
            print('SCISSORS versus...')
            print("PAPER")
            print("You win!")
            print("You have ",a,"ties and ",b,"losses before your first win.")
            win=1
            a=0
            b=0
        elif ran==2:
            print('SCISSORS versus...')
            print("SCISSORS")
            print("It's a tie!")
            a=a+1
# Out:
# Welcome to ROCK, PAPER, SCISSORS game!
# Enter your move: (r)ock (p)aper (s)cissors
# r
# ROCK versus...
# SCISSORS
# You win!
# You have  0 ties and  0 losses before your first win.
